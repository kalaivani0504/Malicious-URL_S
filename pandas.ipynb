# %%
import pandas as pd
import numpy as np

# %%
d = {
    'A': [1,2,np.nan],
    'B':[5, np.nan, np.nan],
    'C':[1,2,3]
}
df=pd.DataFrame(d)
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value='NO DATA')
# Out:
#          A        B  C
# 0      1.0      5.0  1
# 1      2.0  NO DATA  2
# 2  NO DATA  NO DATA  3

# %%
df=pd.DataFrame(d)

# %%
a = df['B'].fillna(value = df['A'].mean())

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
a
# Out:
# 0    5.0
# 1    1.5
# 2    1.5
# Name: B, dtype: float64

# %%
data = {
    'company':['GOOG', 'GOOG', 'IBM', 'MSFT', 'FB', 'FB'],
    'person':['Sam', 'Charlie', 'Amy', 'Vanessa', 'Carl', 'Sarah'],
    'sales':[200, 120, 340, 124, 243, 350]
}
df = pd.DataFrame(data)
df
# Out:
#   company   person  sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2     IBM      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
byComp = df.groupby('company')
byComp.mean(numeric_only= True)
# Out:
#          sales
# company
# FB       296.5
# GOOG     160.0
# IBM      340.0
# MSFT     124.0

# %%
byComp.sum()
# Out:
#              person  sales
# company
# FB        CarlSarah    593
# GOOG     SamCharlie    320
# IBM             Amy    340
# MSFT        Vanessa    124

# %%
df
# Out:
#   company   person  sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2     IBM      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
byComp.std(numeric_only= True)
# Out:
#              sales
# company
# FB       75.660426
# GOOG     56.568542
# IBM            NaN
# MSFT           NaN

# %%
df.groupby('company').count()
# Out:
#          person  sales
# company
# FB            2      2
# GOOG          2      2
# IBM           1      1
# MSFT          1      1

# %%
df
# Out:
#   company   person  sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2     IBM      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.groupby ('company').max()
# Out:
#           person  sales
# company
# FB         Sarah    350
# GOOG         Sam    200
# IBM          Amy    340
# MSFT     Vanessa    124

# %%
df.groupby('company').describe()
# Out:
#         sales
#         count   mean        std    min     25%    50%     75%    max
# company
# FB        2.0  296.5  75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0
# MSFT      1.0  124.0        NaN  124.0  124.00  124.0  124.00  124.0

# %%
import pandas as pd
import numpy as np
d = {
    'data 1':[55,np.nan,33,66],
    'data 2':[11,22,33,np.nan],
    'data 3':[np.nan,200,300,400]
}
df = pd.DataFrame(d)
df
df.dropna()
df.dropna(axis = 0)
df.dropna(axis =1)
df
df.fillna(value = 'NO DATA')
df=pd.DataFrame(d)
a = df['data 2'].fillna(value = df['data 1'].mean())
df
a
df
df['data 2'].fillna(value = df['data 1'].mean())
df
df['data 2'].fillna(value = df['data 2'].mean(), inplace = True)
df
# Out:
# <ipython-input-222-30761629d5eb>:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['data 2'].fillna(value = df['data 2'].mean(), inplace = True)
#    data 1  data 2  data 3
# 0    55.0    11.0     NaN
# 1     NaN    22.0   200.0
# 2    33.0    33.0   300.0
# 3    66.0    22.0   400.0

# %%
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])
df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])

# %%
df1
# Out:
#    W   X   Y
# 1  3   4   3
# 2  1   6   2
# 3  5  17  16
# 4  7   2   2

# %%
df2
# Out:
#     W   X   Y
# 5  29  26  28
# 6  22  21  33
# 7  25  30  32
# 8  38  20  35

# %%
df3
# Out:
#      W   X   Y
# 9   57  53  56
# 10  41  42  42
# 11  42  40  51
# 12  41  40  57

# %%
farme = [df1, df2, df3]

# %%
pd.concat(farme)
# Out:
#      W   X   Y
# 1    3   4   3
# 2    1   6   2
# 3    5  17  16
# 4    7   2   2
# 5   29  26  28
# 6   22  21  33
# 7   25  30  32
# 8   38  20  35
# 9   57  53  56
# 10  41  42  42
# 11  42  40  51
# 12  41  40  57

# %%
pd.concat(farme, axis = 1)
# Out:
#       W     X     Y     W     X     Y     W     X     Y
# 1   3.0   4.0   3.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   1.0   6.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3   5.0  17.0  16.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   7.0   2.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5   NaN   NaN   NaN  29.0  26.0  28.0   NaN   NaN   NaN
# 6   NaN   NaN   NaN  22.0  21.0  33.0   NaN   NaN   NaN
# 7   NaN   NaN   NaN  25.0  30.0  32.0   NaN   NaN   NaN
# 8   NaN   NaN   NaN  38.0  20.0  35.0   NaN   NaN   NaN
# 9   NaN   NaN   NaN   NaN   NaN   NaN  57.0  53.0  56.0
# 10  NaN   NaN   NaN   NaN   NaN   NaN  41.0  42.0  42.0
# 11  NaN   NaN   NaN   NaN   NaN   NaN  42.0  40.0  51.0
# 12  NaN   NaN   NaN   NaN   NaN   NaN  41.0  40.0  57.0

# %%
left = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}

# %%
left = pd.DataFrame(left)

# %%
right = pd.DataFrame(right)

# %%
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C   D
# 0  k0  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
left = {
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}
right = {
    'C':['C0','C2','C3'],
    'D':['D0','D2','D3']
}
left = pd.DataFrame(left, index = ['k0','k1','k2'])
right = pd.DataFrame(right, index = ['k0','k2','k3'])
left
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k2  C2  D2
# k3  C3  D3

# %%
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k2  A2  B2  C2  D2

# %%
df = pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col1'].nunique()
# Out:
# 3

# %%
df['col1'].value_counts()
# Out:
# col1
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %% [markdown]
# def times2(x):
#     return 2*x

# %%
def times2(x):
    return 2*x

# %%
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
 df = pd.read_excel("/content/SampleData.xlsx",sheet_name = 'SalesOrders')

# %%
df.head(10)
# Out:
#    OrderDate   Region       Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East     Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central    Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central   Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central      Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West   Sorvino  Pencil     56       2.99  167.44
# 5 2019-04-01     East     Jones  Binder     60       4.99  299.40
# 6 2019-04-18  Central   Andrews  Pencil     75       1.99  149.25
# 7 2019-05-05  Central   Jardine  Pencil     90       4.99  449.10
# 8 2019-05-22     West  Thompson  Pencil     32       1.99   63.68
# 9 2019-06-08     East     Jones  Binder     60       8.99  539.40

# %%
df.tail()
# Out:
#     OrderDate   Region       Rep    Item  Units  Unit Cost    Total
# 38 2020-10-14     West  Thompson  Binder     57      19.99  1139.43
# 39 2020-10-31  Central   Andrews  Pencil     14       1.29    18.06
# 40 2020-11-17  Central   Jardine  Binder     11       4.99    54.89
# 41 2020-12-04  Central   Jardine  Binder     94      19.99  1879.06
# 42 2020-12-21  Central   Andrews  Binder     28       4.99   139.72

# %%
df.columns
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Cost', 'Total'], dtype='object')

# %%
df.columns.to_list()
# Out:
# ['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Cost', 'Total']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderDate  43 non-null     datetime64[ns]
#  1   Region     43 non-null     object
#  2   Rep        43 non-null     object
#  3   Item       43 non-null     object
#  4   Units      43 non-null     int64
#  5   Unit Cost  43 non-null     float64
#  6   Total      43 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
df.nunique()
# Out:
# OrderDate    43
# Region        3
# Rep          11
# Item          5
# Units        37
# Unit Cost    12
# Total        41
# dtype: int64

# %%
df.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df['20% Dis']=df['Total'].apply(lambda x: x*(20/100))

# %%
df.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total  20% Dis
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05   37.810
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50  199.900
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64   35.928
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73  107.946
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44   33.488

# %%
df['payment'] = df['Total'] - df['20% Dis']

# %%
df.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total  20% Dis  \
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05   37.810
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50  199.900
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64   35.928
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73  107.946
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44   33.488
#
#    payment
# 0  151.240
# 1  799.600
# 2  143.712
# 3  431.784
# 4  133.952

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (12,6))
plt.plot(df['OrderDate'], df['Total'])
plt.show()

# %%
# Create a sample DataFrame with 'OrderDate' and 'Total'
data = {'OrderDate': pd.to_datetime(['2023-01-01', '2023-01-15', '2023-02-01', '2023-02-10', '2023-03-01']),
        'Total': [100, 150, 120, 180, 200]}
sample_df = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(sample_df['OrderDate'], sample_df['Total'])
plt.xlabel('Order Date')
plt.ylabel('Total')
plt.title('Total by Order Date')
plt.show()
